# %%
# !pip install -q torch transformers datasets tokenizers \
    sentence-transformers rank-bm25 pytrec-eval-terrier tqdm scipy comet-ml huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.2/786.2 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.2 MB/s eta 0:00:00

# %%
# !pip install -q mteb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 43.9 MB/s eta 0:00:00

# %%
#  RuSciBenchCiteRetrieval RuBQRetrieval XQuADRetrieval  PublicHealthQA

# %%
import os, sys, logging, json

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(message)s")

# %%
from diploma_code import run_mteb_evaluation
# Out:
# 2026-04-15 20:23:20,145 NumExpr defaulting to 4 threads.
# 2026-04-15 20:23:23,484 TensorFlow version 2.19.0 available.
# 2026-04-15 20:23:23,494 JAX version 0.7.2 available.
# 2026-04-15 20:23:42.490386: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776284623.078630      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776284623.239796      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# run_mteb_evaluation(
#     checkpoint="/kaggle/input/models/vikakuznetzowa/checkpoint-phase2-no-eng-best/pytorch/default/1/checkpoints/checkpoint_phase2_best.pt",
#     output_folder="/kaggle/working/checkpoint_phase2_no_eng_best",
#     tasks=["RuBQRetrieval", "PublicHealthQA"],
#     two_stage=False
# )

# %%
# run_mteb_evaluation(
#     checkpoint="/kaggle/input/models/vikakuznetzowa/checkpoint-phase2-no-eng-best/pytorch/default/1/checkpoints/checkpoint_phase2_best.pt",
#     output_folder="/kaggle/working/checkpoint_phase2_no_eng_best_bm25",
#     tasks=["XQuADRetrieval"],
#     two_stage=True
# )

# %%
# run_mteb_evaluation(
#     checkpoint="/kaggle/input/models/vikakuznetzowa/diploma-phase2/pytorch/default/1/checkpoints/checkpoint_phase2_best.pt",
#     output_folder="/kaggle/working/checkpoint_phase2_best_with_bm25",
#     tasks=["RuSciBenchCiteRetrieval"],
#     two_stage=True
# )

# %%
run_mteb_evaluation(
    checkpoint="antoinelouis/colbert-xm",
    output_folder="/kaggle/working/zero_shot_with_bm25",
    tasks=["RuBQRetrieval", "PublicHealthQA"],
    colbert_xm_faithful=True,
    two_stage=False
)
# Out:
# 2026-04-15 20:24:16,257 Evaluating on cuda
# 2026-04-15 20:24:16,259 ColBERT-XM faithful: encoder -> facebook/xmod-base (запрошенный encoder_name=xlm-roberta-base); X-MOD default_language=ru_RU
# 2026-04-15 20:24:16,483 HTTP Request: HEAD https://huggingface.co/facebook/xmod-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-15 20:24:16,506 HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/facebook/xmod-base/1ff23836a9ee8b9656553630c33506a9a8a59c4f/config.json "HTTP/1.1 200 OK"
# 2026-04-15 20:24:16,533 HTTP Request: GET https://huggingface.co/api/resolve-cache/models/facebook/xmod-base/1ff23836a9ee8b9656553630c33506a9a8a59c4f/config.json "HTTP/1.1 200 OK"
# config.json: 0.00B [00:00, ?B/s]
# 2026-04-15 20:24:16,641 HTTP Request: HEAD https://huggingface.co/facebook/xmod-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# ...

# %%
run_mteb_evaluation(
    checkpoint="antoinelouis/colbert-xm",
    output_folder="/kaggle/working/zero_shot_with_bm25",
    tasks=["RuSciBenchCiteRetrieval", "XQuADRetrieval"],
    colbert_xm_faithful=True,
    two_stage=True
)
# Out:
# 2026-04-15 21:00:52,221 Evaluating on cuda
# 2026-04-15 21:00:52,223 ColBERT-XM faithful: encoder -> facebook/xmod-base (запрошенный encoder_name=xlm-roberta-base); X-MOD default_language=ru_RU
# 2026-04-15 21:00:52,278 HTTP Request: HEAD https://huggingface.co/facebook/xmod-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-15 21:00:52,295 HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/facebook/xmod-base/1ff23836a9ee8b9656553630c33506a9a8a59c4f/config.json "HTTP/1.1 200 OK"
# 2026-04-15 21:00:52,351 HTTP Request: HEAD https://huggingface.co/facebook/xmod-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-15 21:00:52,371 HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/facebook/xmod-base/1ff23836a9ee8b9656553630c33506a9a8a59c4f/tokenizer_config.json "HTTP/1.1 200 OK"
# ...
