# %%
# !pip install -q torch transformers datasets tokenizers \
    sentence-transformers rank-bm25 pytrec-eval-terrier tqdm scipy comet-ml huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.0/787.0 kB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.9 MB/s eta 0:00:00

# %%
# !pip install -q mteb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 66.1 MB/s eta 0:00:00

# %%
#  RuSciBenchCiteRetrieval RuBQRetrieval XQuADRetrieval  PublicHealthQA

# %%
import os, sys, logging, json

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(message)s")

# %%
from diploma_code import run_mteb_evaluation
from diploma_code import (
    run_dense_mteb_retrieval,
    RUMTEB_RETRIEVAL_FOUR_TASKS,
    DENSE_BASELINE_MODEL_IDS,
)

TASKS = list(RUMTEB_RETRIEVAL_FOUR_TASKS)
BATCH_SIZE = 128
OUT_ROOT = os.path.join("/kaggle/working/", "mteb_results_dense")
os.makedirs(OUT_ROOT, exist_ok=True)

print("Tasks:", TASKS)
# Out:
# 2026-05-04 14:54:54,015 NumExpr defaulting to 4 threads.
# 2026-05-04 14:54:55,364 TensorFlow version 2.19.0 available.
# 2026-05-04 14:54:55,367 JAX version 0.7.2 available.
# 2026-05-04 14:55:03.222000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777906503.395931      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777906503.446131      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
run_dense_mteb_retrieval(
    DENSE_BASELINE_MODEL_IDS["E5-base"],
    output_folder=os.path.join(OUT_ROOT, "multilingual-e5-base_rumteb4"),
    tasks=['RuBQRetrieval', 'PublicHealthQA'],
    batch_size=BATCH_SIZE,
    two_stage=False
)
# Out:
# 2026-05-04 14:55:17,786 Dense MTEB retrieval: model_id=intfloat/multilingual-e5-base device=cuda tasks=['RuBQRetrieval', 'PublicHealthQA'] languages=['rus'], two_stage=False, bm25_top_k=2000
# 2026-05-04 14:55:17,790 Load pretrained SentenceTransformer: intfloat/multilingual-e5-base
# 2026-05-04 14:55:17,972 HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-base/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-05-04 14:55:17,981 HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-base/d128750597153bb5987e10b1c3493a34e5a4502a/modules.json "HTTP/1.1 200 OK"
# 2026-05-04 14:55:17,992 HTTP Request: GET https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-base/d128750597153bb5987e10b1c3493a34e5a4502a/modules.json "HTTP/1.1 200 OK"
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# ...

# %%
run_dense_mteb_retrieval(
    DENSE_BASELINE_MODEL_IDS["E5-base"],
    output_folder=os.path.join(OUT_ROOT, "multilingual-e5-base_rumteb4"),
    tasks=['RuSciBenchCiteRetrieval', 'XQuADRetrieval'],
    batch_size=BATCH_SIZE,
    two_stage=True
)
# Out:
# 2026-05-04 15:03:58,543 Dense MTEB retrieval: model_id=intfloat/multilingual-e5-base device=cuda tasks=['RuSciBenchCiteRetrieval', 'XQuADRetrieval'] languages=['rus'], two_stage=True, bm25_top_k=2000
# 2026-05-04 15:03:58,548 Load pretrained SentenceTransformer: intfloat/multilingual-e5-base
# 2026-05-04 15:03:58,648 HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-base/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-05-04 15:03:58,658 HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/intfloat/multilingual-e5-base/d128750597153bb5987e10b1c3493a34e5a4502a/modules.json "HTTP/1.1 200 OK"
# 2026-05-04 15:03:58,764 HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-base/resolve/main/config_sentence_transformers.json "HTTP/1.1 404 Not Found"
# 2026-05-04 15:03:58,874 HTTP Request: HEAD https://huggingface.co/intfloat/multilingual-e5-base/resolve/main/config_sentence_transformers.json "HTTP/1.1 404 Not Found"
# ...
